# %% [markdown]
# #  UC4 - Estatística aplicada à Inteligência Artificial

# %% [markdown]
# ## Aula 1 - Introdução à Estatística
#
# ---
#
# ###  Objetivo da aula
# - Entender o que é estatística
# - Entender o papel da estatística na IA
# - Classificar tipos de dados
#
# ---
#  **Mensagem importante:**
# > IA não é só código. IA é entender dados.

# %% [markdown]
# # O que é Estatística?
#
# Estatística é a área que trabalha com:
#
# - Coleta de dados
# - Organização de dados
# - Análise de dados
# - Tomada de decisão
#
# ---
#
# ## Exemplos
#
# - Média de notas → aprovação
# - Consumo → recomendação
# - Padrões → detecção de fraude

# %% [markdown]
# O objetivo da estatística é transformar dados em informação para apoiar decisões.
#
# ---
#
# ## Dado x Informação
#
# ### Dado
# É um valor bruto, sem contexto.
#
# Exemplos:
# - 25
# - 3000
# - "DF"

# %% [markdown]
# ### Informação
# É o dado interpretado com significado.
#
# Exemplos:
# - 25 anos de idade
# - salário de 3000 reais
# - mora em São Paulo
#
# ---

# %% [markdown]
# ## População e Amostra
#
# ### População
# É o conjunto total de elementos que queremos estudar.
#
# Exemplo:
# - todos os alunos de uma escola
# - todos os clientes de uma empresa
#
# ---
#
# ### Amostra
# É uma parte da população utilizada para análise. Um subconjunto da populacao
#
# Exemplo:
# - 30 alunos de uma turma
# - 100 clientes selecionados
#
# ---

# %% [markdown]
# ### Tipos de amostragem (o mais importante)
# 1. Amostragem aleatória simples
# * Todos têm a mesma chance de ser escolhidos
#
# Exemplo:
#
# sortear nomes de uma lista
#
# (É o método mais correto)
#
# ----
# 2. Amostragem por conveniência
#
# (Escolhe quem está mais fácil)
#
# Exemplo:
#
# entrevistar só quem está na sala
#
# Problema: pode gerar viés

# %% [markdown]
# 3. Amostragem estratificada
#
# (Divide a população em grupos e pega um pouco de cada)
#
# Exemplo:
#
# homens e mulheres
# diferentes idades
#
# (Muito usada em pesquisa)
#
# -----
# 4. Amostragem sistemática
#
# (Seleciona de forma regular)
#
# Exemplo:
#
# a cada 10 pessoas, escolhe 1

# %% [markdown]
# # Estatística na Inteligência Artificial
#
# A IA depende da estatística para funcionar.
#
# | Etapa | Uso da estatística |
# |------|------------------|
# | Coleta | Organização de dados |
# | Treinamento | Cálculo de padrões |
# | Avaliação | Medidas de erro |
# | Decisão | Probabilidade |
#
# ---
#
# Sem estatística, a IA não consegue aprender.

# %% [markdown]
# # Tipos de Dados

# %% [markdown]
# ## Variável
#
# Variável é qualquer característica que pode ser observada ou medida.
#
# Exemplos:
# - idade
# - salário
# - cidade
# - nota
#
# ---

# %% [markdown]
# ## Variáveis Qualitativas
#
# - Não são numéricas (ou não fazem sentido calcular)
# - Representam categorias
#
# Ex:
# - Nome
# - Cor
# - Cidade
# - Estado civil
#
# ---
#
# ## Variáveis Quantitativas
#
# - São numéricas
# - Permitem cálculos
#
# Ex:
# - Idade
# - Salário
# - Altura
# - Quantidade

# %% [markdown]
# ## Variáveis Quantitativas (Subtipos)
#
# ###  Discretos
# - Valores inteiros
# - Contáveis
#
# Ex:
# - Número de filhos
# - Número de compras
#
# ---
#
# ###  Contínuos
# - Podem ter qualquer valor
# 34    Casado  2o. Grau       2.0    19.40   48.0   capital      6.00      9.00
# 35    Casado  superior       3.0    23.30   42.0  interior      2.50     44.00

# %% [markdown]
# # Análise
#
# Responda:
#
# 1. Qual coluna é qualitativa?
# 2. Qual coluna é quantitativa?
# 3. Qual coluna representa valores contínuos?
#
# ---
#
#  Escreva suas respostas abaixo:

# %%
# Resposta
# 1. As variaveis qualitativas são: estado civil, grau de escolaridade, origem
# 2. As colunas quantitativas são: numero de filhos, idade e quantidade de salarios
# 3. Quantidade de salarios

# %% [markdown]
# # Exercício 1
#
# Classifique:
#
# | Dado | Tipo |
# |------|-----|
# | Nome | |
# | Idade | |
# | Salário | |
# | Cor favorita | |
# | Número de filhos | |

# %%
# Nome - Categorica nominal
# Idade - Continua
# Salario - Continua
# Cor favorita - Categorica nominal
# Numero de filhos - Discreta

# %% [markdown]
# # Exercício 2
#
# Classifique como:
#
# - Qualitativo
# - Quantitativo discreto
# - Quantitativo contínuo
#
# | Dado | Tipo |
# |------|-----|
# | Altura | |
# | Número de alunos | |
# | Temperatura | |
# | Salário | |

# %%
# Altura - Quantitativo contínuo
# Numero de alunos - Quantitativo discreto
# Temperatura - Quantitativo contínuo
# Salário - Quantitativo contínuo

# %% [markdown]
# #  Exercício 3
#
# Classifique cada coluna do dataset acima:
#
# - produto
# - preco
# - quantidade_vendida
# - categoria

# %%
dados = {
    "produto": ["Arroz", "Feijão", "Macarrão"],
    "preco": [16.00, 6.50, 5.50],
    "quantidade_vendida": [10, 50, 30],
    "categoria": ["grão", "grão", "massa"]
}
dados
# Out:
# {'produto': ['Arroz', 'Feijão', 'Macarrão'],
#  'preco': [16.0, 6.5, 5.5],
#  'quantidade_vendida': [10, 50, 30],
#  'categoria': ['grão', 'grão', 'massa']}

# %% [markdown]
# ## Reforço

# %% [markdown]
# ###Classifique os dados abaixo:
#
# - CPF
# - Temperatura
# - Placa de carro
# - Altura
# - Número de curtidas no Instagram
# - CEP
# - Salário
# - Tipo sanguíneo

# %% [markdown]
# ### Se você fosse criar uma IA para recomendar filmes, quais dados você usaria?

# %% [markdown]
# ### Explorando dados no Python
#
# - ´df.info´ e ´df.describe()´

# %% [markdown]
# ### Desafio final

# %%
dados = {
    "idade": [18, 25, 40, 60],
    "compra": ["sim", "sim", "não", "não"]
}

# %% [markdown]
# Se chega uma pessoa com 30 anos, ela compraria?

# %% [markdown]
# “Com base em quê?”
#
# “Achismo ou dados?”

# %% [markdown]
# “Nosso cérebro quer encontrar padrão rápido.
# Mas a estatística exige evidência.”

# %% [markdown]
# “Com poucos dados, a IA também erra.”

# %% [markdown]
# Você pode falar:
#
# “Se tivéssemos MUITOS dados, poderíamos modelar isso”
#
# Exemplo:
#
# regressão (idade vs compra)
# probabilidade condicional
#
# Aí você conecta com IA de verdade

# %% [markdown]
# #  Conclusão
#
# Hoje você aprendeu:
#
# - O que é estatística
# - A importância dela na IA
# - Tipos de dados
# - Discreto vs contínuo
#
# ---
#
#  Na próxima aula:
# Vamos começar a analisar dados de verdade (média, moda, etc).
#
# ---
#
#  Lembre-se:
# > IA começa com entender dados.
